# %%
 Q1-Who developed python programming language ?


Ans- Python programming language was developed by Guido van Rossum in the late 1980s and was first released in 1991.



Q2-Which type of programming does pyhon support?

Ans- Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Additionally, 
it also has features for aspect-oriented and procedural-oriented programming.
This makes it a versatile and flexible language for a wide range of tasks.


Q3- Is python case sensitive when dealing with identifiers?

Ans- Yes, Python is case sensitive when dealing with identifiers, 
33blet example, names like "karan" and "Karan" would be considered as two different variables.


Q4-what is the correct extension of python file?

Ans- The correct extension for Python files is ".py".


Q5-is python code is compiled or interpreted ?


Ans - Python code is interpreted, not compiled.



Q6-name a few blocks of code used to define in python language?


Ans - A few blocks of code used to define in the Python language are:

` 1. Classes: used to create objects and define their properties and methods.

  2. Loops: including "for" and "while" loops, used to repeatedly execute code blocks.

3.   Conditional statements: such as "if" and "if-else" statements, used to execute code blocks based on certain conditions.




Q7. state a character used to give single- line comments in python ?

Ans - The character used to give single-line comments in Python is the hash symbol (#).
    For example:
    
             # Hay body! this is karn.
    
    
 Q8-mention function which can help us to find the version of python
    that we are curruntly working on?
    
Ans- The function sys.version or sys.version_info can be used to find the version of Python that you are currently working on. 
    Here's an example:    

    import sys

print("Python version")
print(sys.version)
print("Version info.")
print(sys.version_info)
    
    
    
    
Q9-   python supports the creation of anonymous functions at runtime,
    using conctruct called ?

Ans- In Python, anonymous functions at runtime can be created using the "lambda" keyword. These functions are also known as "lambda functions".
    
    
    
Q.10- what does pip stand for python?   
    
    
Ans- "pip" stands for "Pip Installs Packages". It is a package management system for Python, used to install and manage software packages written in Python.
    
    
Q11- Mention a few built in fuctions in python ?
    
    
Ans -  Here are a few built-in functions in Python:

print(): used to print the output of a program.

len(): used to find the length of a list, string, or any other object that has a length.

range(): used to generate a range of numbers.

sum(): used to find the sum of a list of numbers.

min() and max(): used to find the minimum and maximum values of a list, respectively.

# %%
Q12- What is the maximum possible length of an identifier in python ?

Ans - There is no specific maximum length for identifiers in Python.
An identifier can be of any length,
as long as it only contains letters, numbers, 
and underscores and does not start with a number. 


Q13. what are the benefits of using python ?

Ans-There are several benefits to using Python as a programming language:

Easy to Learn: Python has a simple and intuitive syntax, making it easy for both new and experienced programmers to pick up and start using.

Versatile: Python can be used for a wide range of tasks, including web development, scientific computing, data analysis, artificial intelligence, and more.

Large Community: Python has a large and active community of developers, who have created a wealth of resources, libraries, and tools to support the language.



Q14- How is memory managed in python?

Ans- In Python, memory management is handled automatically by the Python memory manager and the underlying operating system.
The Python memory manager keeps track of the memory used by Python objects and manages the allocation and deallocation of that memory.


Q15-how to install python on windows and set path variables ?


ans - To install Python on Windows and set the path variables, you can follow these steps:

Download the Python installer: Go to the official Python website (https://www.python.org/downloads/) and download the latest version of Python for Windows.

Run the installer: Double-click the downloaded Python installer file and follow the instructions to install Python on your system.
Make sure to select the option to add Python to your path during the installation process.

Verify the installation: Open the Command Prompt and type "python" to verify that Python has been installed and the path variable has been set correctly.
If the installation was successful, you should see the Python prompt.

Set the path variable: If the path variable was not set during the installation, you can set it manually. To do this, follow these steps:

Right-click on the Windows start button and select "System"
Click on "Advanced system settings"
Click on the "Environment Variables" button
Under "System Variables", find the "Path" variable and click "Edit"
Add the path to the Python installation to the end of the "Variable value" field (for example, "C:\Python38")
Click OK to save the changes.
Now that the path variable has been set, you should be able to run Python from any location on your system by typing "python" in the Command Prompt.


Q16-is indentation required in python ?

ans -Yes, indentation is required in Python. 
It is used to define code blocks and control structures such as loops and functions
